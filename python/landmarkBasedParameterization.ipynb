# %%
# !ls ../../Data/
# Out:
# twoBlob.csv

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('../../Data/twoBlob.csv')
data.head()
# Out:
#    -0.97135  -0.051743   0.1898  -0.04336   0.12612
# 0  -0.96939   0.194200  0.10836  0.000566 -0.104100
# 1  -0.96315  -0.019171  0.26286 -0.036703  0.039101
# 2  -0.96283   0.132720 -0.19384 -0.126880  0.040860
# 3  -0.95502   0.259800  0.12170  0.067138  0.033398
# 4  -0.95133  -0.003512  0.18421  0.246390 -0.017659

# %%
pd.plotting.scatter_matrix(data,figsize=[10,10]);
